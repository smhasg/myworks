# %%
! pip install WorldCloud
# Out:
# ...
#   Could not find a version that satisfies the requirement WorldCloud (from versions: )
# No matching distribution found for WorldCloud

# %%
import os 
import pandas as pd

# %%
 os.system("dir")
# Out:
# 0

# %%
df= pd.read_excel("/Users/smhasg/Desktop/Book1.xlsx")

# %%
df
# Out:
#             كد كالا             نام كالا    مبلغ كل   معدل في  تعداد-عدد  \
# 0    0090/0000/5250  MCB 052TRBC09-7-2RS   14136600    706830         20
# 1    0090/0000/9067        MCB 09067/195     156750     52250          3
# 2    0090/0001/1749         MCB 11749/10  151628614    200302        757
# 3    0090/0001/1949         MCB 11949/10   47714472    139516        342
# 4    0090/0001/2040             MCB 1204    5005000    250250         20
# ..              ...                  ...        ...       ...        ...
# 511  0090/1000/0235                 B-85    6840800   3420400          2
# 512  0090/1000/1085              4PK-885   22146383  22146383          1
# 513  0090/1000/1130              4PK-930   29219582    596318         49
# 514  0090/1000/3163             6PK-1663   30402488  30402488          1
# 515  0090/1000/3164    LA 9/5*1500 CHINA    6360000    795000          8
#
#      مبلغ  معدل في.1  تعداد-عدد.1  وارده  معدل في.2  تعداد  تعداد ابتداي دوره  \
# ...

# %%
cdf= df.drop(["كد كالا","معدل في.1","معدل في","مبلغ كل","معدل في.2","موجودي ابتداي دوره","مبلغ"],axis=1)

# %%
cdf.head(20)
# Out:
#                نام كالا  تعداد-عدد  تعداد-عدد.1  وارده  تعداد  \
# 0   MCB 052TRBC09-7-2RS         20            0      0      0
# 1         MCB 09067/195          3            0      0      0
# 2          MCB 11749/10        757            0      0      0
# 3          MCB 11949/10        342            0      0      0
# 4              MCB 1204         20            0      0      0
# 5              MCB 1205        192            0      0      0
# 6            MCB 1206-K         70            0      0      0
# 7            MCB 1207-K         39            0      0      0
# 8            MCB 1208-K         36            0      0      0
# 9            MCB 1209-K         15            0      0      0
# 10           MCB 1210-K         36            0      0      0
# 11           MCB 1212-K         41            0      0      0
# 12      MCB 1212-K+H212          1            0      0      0
# 13           MCB 1213-K          6            0      0      0
# ...
