# %% [markdown]
# # Pandas
#
# [Pandas](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# ### Installation:
#
# <div class="alert alert-block alert-warning">
# $ pip install pandas
# </div>

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/khamir/opt/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Series
#
# Defining a Series

# %%
obj = pd.Series([4, 7, -5, 3])

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj[1]
# Out:
# 7

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['a', 'b', 'c', 'd'])

# %%
obj2
# Out:
# a    4
# b    7
# c   -5
# d    3
# dtype: int64

# %%
obj2['b']
# Out:
# 7

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['d'] = -3
obj2
# Out:
# a    4
# b    7
# c   -5
# d   -3
# dtype: int64

# %%
obj2[['b', 'c']]
# Out:
# b    7
# c   -5
# dtype: int64

# %%
obj2[obj2>0]
# Out:
# a    4
# b    7
# dtype: int64

# %%
pd.Series([1000, 1001, 1002, 1001, 1002], index=pd.date_range("2018-01-01", periods=5, freq="2D"))
# Out:
# 2018-01-01    1000
# 2018-01-03    1001
# 2018-01-05    1002
# 2018-01-07    1001
# 2018-01-09    1002
# Freq: 2D, dtype: int64

# %% [markdown]
# # DataFrame
#
# Defining a DataFrame using dictionary

# %%
sdata = {'Ohio': [3500, 4000],
         'Tehran': [5000, 3200],
         'Utah': [2030, 3030]}
df = pd.DataFrame(sdata)

# %%
df
# Out:
#    Ohio  Tehran  Utah
# 0  3500    5000  2030
# 1  4000    3200  3030

# %%
import numpy as np

# %%
arr = np.random.uniform(0, 1000, (100, 6))

# %%
df = pd.DataFrame(arr, columns=['a', 'b', 'c', 'd', 'e', 'f'])

# %% [markdown]
# # Viewing data
#
# + head and tail
# + index and columns
# + to_numpy
# + describe and info
# + sorting

# %%
df.head(12)
# Out:
#              a           b           c           d           e           f
# 0   252.978743  283.779307   67.866077  448.775774  874.436497  152.516189
# 1   750.661393  250.442725  334.221130  623.139169  159.391474  715.707957
# 2     8.779598  833.145728  122.605304  456.812921  557.341705  701.604572
# 3    52.993377    4.640474  238.707753  744.304726  195.705725  358.242964
# 4   304.762086  990.485113  597.410274  372.621010  321.062138  242.275668
# 5   567.248569  614.875342   28.579365   37.194229  364.425348  824.476525
# 6    20.013374   76.959774  314.293344  874.434973  864.104467  994.014030
# 7    51.966211  908.137531  797.543221  670.052057  197.197934  155.670844
# 8   910.760143  551.358996  598.394414  189.637742  151.382031  952.691065
# 9   335.744964  506.889128  639.561961  645.794871  245.463964  550.709499
# 10  440.619935  593.583213  311.903754  376.132099  202.202532  715.936682
# 11  725.486063  701.861347  753.425719  893.633409  383.737001  679.026736

# %%
df.tail()
# Out:
#              a           b           c           d           e           f
# 95  502.896728  360.044236  357.973938   56.171640   85.166332  720.667804
# 96  511.580495  970.687371  857.601580  561.638891  456.824636  588.579954
# 97  301.782906   81.695747  732.595398   43.035801  996.791783  617.495754
# 98   87.999900  611.332882  948.207611  393.782958  139.855947  639.687342
# 99  255.056085   20.148866  153.525874  805.531490  969.594018  795.730755

# %%
df.tail(3)
# Out:
#              a           b           c           d           e           f
# 97  301.782906   81.695747  732.595398   43.035801  996.791783  617.495754
# 98   87.999900  611.332882  948.207611  393.782958  139.855947  639.687342
# 99  255.056085   20.148866  153.525874  805.531490  969.594018  795.730755

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df['c']
# Out:
# 0      67.866077
# 1     334.221130
# 2     122.605304
# 3     238.707753
# 4     597.410274
#          ...
# 95    357.973938
# 96    857.601580
# 97    732.595398
# 98    948.207611
# 99    153.525874
# Name: c, Length: 100, dtype: float64

# %%
df[['c', 'e']].tail(6)
# Out:
#              c           e
# 94  817.176923   93.092115
# 95  357.973938   85.166332
# 96  857.601580  456.824636
# 97  732.595398  996.791783
# 98  948.207611  139.855947
# 99  153.525874  969.594018

# %%
df[['c', 'e']].head(6)
# Out:
#             c           e
# 0   67.866077  874.436497
# 1  334.221130  159.391474
# 2  122.605304  557.341705
# 3  238.707753  195.705725
# 4  597.410274  321.062138
# 5   28.579365  364.425348

# %%
df.iloc[1, :]
# Out:
# a    750.661393
# b    250.442725
# c    334.221130
# d    623.139169
# e    159.391474
# f    715.707957
# Name: 1, dtype: float64

# %%
df.iloc[:, 1]
# Out:
# 0     283.779307
# 1     250.442725
# 2     833.145728
# 3       4.640474
# 4     990.485113
#          ...
# 95    360.044236
# 96    970.687371
# 97     81.695747
# 98    611.332882
# 99     20.148866
# Name: b, Length: 100, dtype: float64

# %%
df.iloc[30:60, [1, 3]]
# Out:
#              b           d
# 30  768.643182  906.279342
# 31  984.659316  700.042491
# 32  636.926984   92.769320
# 33  521.332753  649.877577
# 34  213.749876  430.047075
# 35  470.585544  544.782564
# 36  479.615856  253.019097
# 37  228.262723  317.416977
# 38  385.001700  771.405671
# 39  191.340666  655.981224
# 40  166.160285  347.089811
# 41  231.128734  338.145175
# 42  596.201753  990.867614
# 43  472.911022  740.691796
# 44   33.005115  674.247019
# 45  825.141861  785.927850
# 46  374.195770  128.505797
# 47  687.645006  302.737960
# 48  249.166886  985.803581
# 49  877.192148  772.076156
# 50  414.912819  720.159768
# 51  666.181724  760.640461
# 52  936.947028  215.814507
# 53  321.580452  497.464599
# 54  417.889606  544.990742
# 55  107.299700   35.417092
# 56  600.627764   32.469837
# 57  655.454033  674.554866
# 58  350.715562    1.798502
# 59  407.531598  465.819409

# %%
df.loc[2]
# Out:
# a      8.779598
# b    833.145728
# c    122.605304
# d    456.812921
# e    557.341705
# f    701.604572
# Name: 2, dtype: float64

# %%
df.loc[30:60, ['a', 'c']]
# Out:
#              a           c
# 30  776.092976  366.428476
# 31   76.565772  119.838037
# 32  855.265070  360.572480
# 33  405.156378   64.208835
# 34  734.700014   94.182498
# 35   71.097584  826.075063
# 36  345.543950  113.463766
# 37  914.622362  370.439700
# 38   78.813865  144.621362
# 39  370.983008  649.759230
# 40  365.180440  954.179436
# 41  454.023844  845.111809
# 42  173.735299  275.618278
# 43  987.102533  631.710924
# 44  257.097005  899.499066
# 45  304.524607  831.426686
# 46  553.332536  954.607638
# 47  571.387601  319.461657
# 48  888.642328  806.903673
# 49    0.601483  214.823201
# 50  608.743945  578.960774
# 51  878.108440  364.147116
# 52  295.045492  824.827561
# 53  739.395042    6.345523
# 54  754.920767  840.475318
# 55  469.645137  229.524597
# 56  337.168320  848.586606
# 57  445.520245  870.367728
# 58   74.469587  352.057606
# 59  353.013042  843.492576
# 60  578.328001  199.624290

# %%
df.describe()
# Out:
#                 a           b           c           d           e           f
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean   462.521996  472.737233  483.604911  529.064522  424.358650  523.239840
# std    273.801082  287.193835  284.852867  278.634726  274.715691  274.546273
# min      0.601483    4.032009    6.345523    1.798502    0.442964    5.686224
# 25%    251.892849  224.634511  229.922596  313.747223  194.671820  307.063041
# 50%    462.421947  471.748283  450.565126  581.648048  390.306545  567.722827
# 75%    696.455484  677.875583  742.042353  746.523581  639.390984  742.108917
# max    987.102533  999.328741  954.607638  992.169763  996.791783  994.879281

# %%
df['s'] = [str(i) for i in range(1, 101)]
df['i'] = [i for i in range(1, 101)]

# %%
df
# Out:
#              a           b           c           d           e           f  \
# 0   252.978743  283.779307   67.866077  448.775774  874.436497  152.516189
# 1   750.661393  250.442725  334.221130  623.139169  159.391474  715.707957
# 2     8.779598  833.145728  122.605304  456.812921  557.341705  701.604572
# 3    52.993377    4.640474  238.707753  744.304726  195.705725  358.242964
# 4   304.762086  990.485113  597.410274  372.621010  321.062138  242.275668
# ..         ...         ...         ...         ...         ...         ...
# 95  502.896728  360.044236  357.973938   56.171640   85.166332  720.667804
# 96  511.580495  970.687371  857.601580  561.638891  456.824636  588.579954
# 97  301.782906   81.695747  732.595398   43.035801  996.791783  617.495754
# 98   87.999900  611.332882  948.207611  393.782958  139.855947  639.687342
# 99  255.056085   20.148866  153.525874  805.531490  969.594018  795.730755
#
#       s    i
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 8 columns]

# %%
df.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean   462.521996  472.737233  483.604911  529.064522  424.358650  523.239840
# std    273.801082  287.193835  284.852867  278.634726  274.715691  274.546273
# min      0.601483    4.032009    6.345523    1.798502    0.442964    5.686224
# 25%    251.892849  224.634511  229.922596  313.747223  194.671820  307.063041
# 50%    462.421947  471.748283  450.565126  581.648048  390.306545  567.722827
# 75%    696.455484  677.875583  742.042353  746.523581  639.390984  742.108917
# max    987.102533  999.328741  954.607638  992.169763  996.791783  994.879281
#
#                 i
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.iloc[3:6, [1, 3]] = None
df.iloc[10:17, [2, 4]] = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       100 non-null    float64
#  1   b       97 non-null     float64
#  2   c       93 non-null     float64
#  3   d       97 non-null     float64
#  4   e       93 non-null     float64
#  5   f       100 non-null    float64
#  6   s       100 non-null    object
#  7   i       100 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
dic = {'name':['Amir', 'Deli', 'Ali', 'Hosei', 'Danial', 'Amir'],
       'age': [25, 23, 33, 37, 24, 24],
       'phone':[12345678, 3249837, 1234567, 98765, 5678, 30428393]}
data = pd.DataFrame(dic)

# %%
data
# Out:
#      name  age     phone
# 0    Amir   25  12345678
# 1    Deli   23   3249837
# 2     Ali   33   1234567
# 3   Hosei   37     98765
# 4  Danial   24      5678
# 5    Amir   24  30428393

# %%
# data = data.sort_values(['name', 'age'], ascending=False, inplace=True).reset_index(drop=True)
data.sort_values(['name', 'age'], ascending=False, inplace=True)
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Missing data
#
# + isna and isnull
# + dropna and fillna

# %%
np.sum(df.isna())
# Out:
# a    0
# b    3
# c    7
# d    3
# e    7
# f    0
# s    0
# i    0
# dtype: int64

# %%
np.sum(df.isnull())
# Out:
# a    0
# b    3
# c    7
# d    3
# e    7
# f    0
# s    0
# i    0
# dtype: int64

# %%
df.fillna(-1)
# Out:
#              a           b           c           d           e           f  \
# 0   252.978743  283.779307   67.866077  448.775774  874.436497  152.516189
# 1   750.661393  250.442725  334.221130  623.139169  159.391474  715.707957
# 2     8.779598  833.145728  122.605304  456.812921  557.341705  701.604572
# 3    52.993377   -1.000000  238.707753   -1.000000  195.705725  358.242964
# 4   304.762086   -1.000000  597.410274   -1.000000  321.062138  242.275668
# ..         ...         ...         ...         ...         ...         ...
# 95  502.896728  360.044236  357.973938   56.171640   85.166332  720.667804
# 96  511.580495  970.687371  857.601580  561.638891  456.824636  588.579954
# 97  301.782906   81.695747  732.595398   43.035801  996.791783  617.495754
# 98   87.999900  611.332882  948.207611  393.782958  139.855947  639.687342
# 99  255.056085   20.148866  153.525874  805.531490  969.594018  795.730755
#
#       s    i
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 8 columns]

# %%
df.dropna(inplace=True)

# %%
np.sum(df.isnull())
# Out:
# a    0
# b    0
# c    0
# d    0
# e    0
# f    0
# s    0
# i    0
# dtype: int64

# %% [markdown]
# # Operations
#
# + mean
# + std
# + apply

# %%
df.mean(axis=1, numeric_only=True)
# Out:
# 0     297.336084
# 1     405.080550
# 2     383.327118
# 6     450.117137
# 7     398.366828
#          ...
# 95    311.274383
# 96    577.701847
# 97    410.199627
# 98    417.123806
# 99    442.798156
# Length: 90, dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# a    77025.849837
# b    82651.346397
# c    83510.513339
# d    79949.060654
# e    77503.806509
# f    76308.450093
# i      742.147441
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# a    277.535313
# b    287.491472
# c    288.981856
# d    282.752649
# e    278.395055
# f    276.239842
# i     27.242383
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# a    41639.029176
# b    41456.521004
# c    44354.891634
# d    48382.994492
# e    39230.203894
# f    46528.560874
# i     4937.000000
# dtype: float64

# %%
df.min()
# Out:
# a    0.601483
# b    4.032009
# c    6.345523
# d    1.798502
# e    0.442964
# f    5.686224
# s           1
# i           1
# dtype: object

# %%
df['h'] = True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       90 non-null     float64
#  1   b       90 non-null     float64
#  2   c       90 non-null     float64
#  3   d       90 non-null     float64
#  4   e       90 non-null     float64
#  5   f       90 non-null     float64
#  6   s       90 non-null     object
#  7   i       90 non-null     int64
#  8   h       90 non-null     bool
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
def f(x):
    float_type = [np.float64, np.float32, np.float16]
    int_type = [np.int8, np.int16, np.int32, np.int64]
    if x.dtype in float_type or x.dtype in int_type:
        return np.max(x) - np.mean(x)
    else:
        return None

# %%
df.apply(f)
# Out:
# a    524.446654
# b    538.700730
# c    461.775509
# d    454.580935
# e    560.900628
# f    477.895272
# s           NaN
# i     45.144444
# h           NaN
# dtype: float64

# %%
new_df.mean(numeric_only=True)
# Out:
# a   -7.326485e-14
# b   -1.263187e-15
# c    6.315935e-15
# d    1.035813e-13
# e    2.400055e-14
# f    5.305386e-14
# i    1.263187e-15
# h    1.000000e+00
# dtype: float64

# %% [markdown]
# # Merging
#
# + concat
# + merge
# + append
# + join

# %%
data.append(pd.DataFrame({'name':['Rose'],
                          'age': [23],
                          'phone':[123456]})).reset_index(drop=True)
# Out:
# /var/folders/56/qbnffzv10bg6kcp5fhsvg2dh0000gn/T/ipykernel_18411/3167739258.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append(pd.DataFrame({'name':['Rose'],
#      name  age     phone
# 0   Hosei   37     98765
# 1    Deli   23   3249837
# 2  Danial   24      5678
# 3    Amir   25  12345678
# 4    Amir   24  30428393
# 5     Ali   33   1234567
# 6    Rose   23    123456

# %%
dic = {'name':['Amir', 'Deli', 'Ali', 'Hosei', 'Danial', 'Amir'],
       'age': [25, 23, 33, 37, 24, 24],
       'phone':[12345678, 3249837, 1234567, 98765, 5678, 30428393]}
data1 = pd.DataFrame(dic)

# %%
dic = {'name':['Reza', 'Nazi'],
       'age': [25, 23],
       'phone':[2304032, 3284989]}
data2 = pd.DataFrame(dic)

# %%
dic = {'name':['Gholi', 'abdola'],
       'age': [52, 43],
       'phone':[32923, 323242]}
data3 = pd.DataFrame(dic)

# %%
pd.concat([data1, data2, data3]).reset_index(drop=True)
# Out:
#      name  age     phone
# 0    Amir   25  12345678
# 1    Deli   23   3249837
# 2     Ali   33   1234567
# 3   Hosei   37     98765
# 4  Danial   24      5678
# 5    Amir   24  30428393
# 6    Reza   25   2304032
# 7    Nazi   23   3284989
# 8   Gholi   52     32923
# 9  abdola   43    323242

# %%
dic = {'name':['Amir', 'Deli', 'Ali', 'Hosei', 'Danial'],
       'age': [25, 23, 33, 37, 24, ]}
data1 = pd.DataFrame(dic)

# %%
data1
# Out:
#      name  age
# 0    Amir   25
# 1    Deli   23
# 2     Ali   33
# 3   Hosei   37
# 4  Danial   24

# %%
dic = {'name':['Amir', 'Deli', 'Ali', 'Hosei', 'Danial', 'Mirza'],
       'weight': [76, 56, 93, 69, 120, 89],
       'height': [180, 160, 170, 156, 195, 170]}
data2 = pd.DataFrame(dic)

# %%
data2
# Out:
#      name  weight  height
# 0    Amir      76     180
# 1    Deli      56     160
# 2     Ali      93     170
# 3   Hosei      69     156
# 4  Danial     120     195
# 5   Mirza      89     170

# %%
pd.merge(data1, data2, on='name')
# Out:
#      name  age  weight  height
# 0    Amir   25      76     180
# 1    Deli   23      56     160
# 2     Ali   33      93     170
# 3   Hosei   37      69     156
# 4  Danial   24     120     195

# %%
pd.merge(data2, data1, on='name')
# Out:
#      name  weight  height  age
# 0    Amir      76     180   25
# 1    Deli      56     160   23
# 2     Ali      93     170   33
# 3   Hosei      69     156   37
# 4  Danial     120     195   24

# %%
data2.join(data1.set_index('name'), on='name')
# Out:
#      name  weight  height   age
# 0    Amir      76     180  25.0
# 1    Deli      56     160  23.0
# 2     Ali      93     170  33.0
# 3   Hosei      69     156  37.0
# 4  Danial     120     195  24.0
# 5   Mirza      89     170   NaN

# %% [markdown]
# # Reading and Writing
#
# + read_csv and to_csv
# + read_excel

# %%
data2.to_csv('data2.csv')

# %%
loaded_data = pd.read_csv('data2.csv', index_col=0)

# %%
loaded_data
# Out:
#      name  weight  height
# 0    Amir      76     180
# 1    Deli      56     160
# 2     Ali      93     170
# 3   Hosei      69     156
# 4  Danial     120     195
# 5   Mirza      89     170

# %%
data = pd.read_excel('/Users/khamir/Desktop/tDCS-Anxiety/BART/BART.xlsx', engine='openpyxl')

# %%
data
# Out:
#         Name  Age  Gender  Sideness  Arrangement  Diagnosis  BARTshmAccount  \
# 0     M.Reza   18       2         1            1          1          416000
# 1   Mahdiyeh   22       1         2            2          1          400000
# 2    Fatemeh   31       1         1            3          1          488000
# 3    Masumeh   35       1         1            4          3          912000
# 4   A.Mohamd   17       2         1            5          1          201000
# 5     Fariba   19       1         1            6          1          816000
# 6      Zahra   45       1         1            7          2          489000
# 7   Faezeh.A   27       1         1            9          1          457000
# 8      Akram   36       1         1           10          4          862000
# 9   Hamidrez   21       2         1           11          1          823000
# 10   M.Javad   34       2         1           12          3          977000
# 11    Zohreh   35       1         1           13          3          518000
# 12   Mehrdad   24       2         1           14          1          777000
# 13  Alireza.   36       2         1           15          1          866000
# 14    Hanieh   20       1         1           16          4          703000
# 15     Saeed   36       2         1           17          4          976000
# 16     Mahur   20       1         1           18          1          525000
# 17   Afsaneh   32       1         1           19          1          382000
#
#     BARTshmPN  BARTshmSUC  BARTshmAV  ...  BARTrarmT21  BARTrarmT22  \
# 0          10          20    20.8000  ...       10.940       13.640
# 1           9          21    19.0476  ...       12.670       48.000
# 2           5          25    19.5200  ...       13.920        9.440
# 3           7          23    39.6522  ...        5.200        3.420
# 4           0          30     6.7000  ...        4.431        4.586
# 5           7          23    35.4783  ...       12.570       16.520
# 6           2          28    17.4643  ...       22.350        0.060
# 7           8          22    20.7727  ...       11.430        6.260
# 8           7          23    37.4783  ...       14.500       12.630
# 9          12          18    45.7222  ...       16.660       16.510
# 10          9          21    46.5238  ...       21.250        9.290
# 11          6          24    21.5833  ...       10.180       10.180
# 12         13          17    45.7059  ...       12.500       12.580
# 13         15          15    57.7333  ...       30.270       13.690
# 14         10          20    35.1500  ...       16.880       20.450
# 15          9          21    46.4762  ...        9.660        9.830
# 16          7          23    22.8261  ...       13.930       13.240
# 17          1          29    13.1724  ...       16.970       16.820
#
#     BARTrarmT23  BARTrarmT24  BARTrarmT25  BARTrarmT26  BARTrarmT27  \
# 0        15.740       15.790       12.440       15.410        0.850
# 1        25.380       31.641       45.940       57.670       23.750
# 2        12.420       16.560       11.800        4.080        9.350
# 3         5.730       15.160        5.430       12.330       12.880
# 4         4.664        3.698        4.992        0.078        4.914
# 5        17.890        9.890        3.520       18.380        1.150
# 6        21.960        0.060        8.380       14.510        0.070
# 7        15.430       16.500        9.940        7.700        6.360
# 8         8.690       17.300       13.430       14.030        9.910
# 9         6.130       24.910       15.500       13.750       14.410
# 10       12.320       13.690       17.370       16.630        7.590
# 11        9.830       10.980       10.760        9.470       10.200
# 12       11.140        3.320        5.280        8.200       11.480
# 13       12.090       33.620       19.650       29.510        5.240
# 14        7.620       16.900        7.880       23.110       16.380
# 15        0.170       10.080        8.430       10.500        9.300
# 16        4.120        4.730        8.520        1.300       11.560
# 17        4.090       14.880       10.240       10.970       12.280
#
#     BARTrarmT28  BARTrarmT29  BARTrarmT30
# 0         0.630        0.750        0.470
# 1        57.820       13.070       72.620
# 2         4.890        9.950       12.310
# 3        11.480       12.820        9.610
# 4         3.260        3.666        5.554
# 5        12.860       16.670       16.080
# 6        16.670        0.070        0.360
# 7        12.471       17.570       14.150
# 8         3.930        1.090        3.950
# 9        24.580       12.810       17.220
# 10        3.380       13.940       21.910
# 11       10.430        5.750        1.570
# 12       10.650       12.090       12.060
# 13       33.220       10.690       30.610
# 14       10.100       26.610       10.950
# 15        8.761        8.740        7.920
# 16       19.240       16.370       12.630
# 17        9.110       11.090        9.440
#
# [18 rows x 501 columns]
