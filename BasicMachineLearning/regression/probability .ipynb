# %%
import pandas as pd 
import numpy as np 
#import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-5b3237f2fea1> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 #import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/__init__.py in <module>()
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import (
#      23     _np_version_under1p16,
#      24     _np_version_under1p17,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/compat/numpy/__init__.py in <module>()
#      19 if _nlv < "1.15.4":
#      20     raise ImportError(
# ---> 21         "this version of pandas is incompatible with numpy < 1.15.4\n"
#      22         f"your numpy version is {_np_version}.\n"
#      23         "Please upgrade numpy to >= 1.15.4 to use this pandas version"
#
# ...

# %%
data =pd.read_csv("../DATA/activity.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ca5f0a960230> in <module>()
# ----> 1 data =pd.read_csv("../DATA/activity.csv")
#       2 data.head()
#
# NameError: name 'pd' is not defined

# %%
if data.isnull().sum().sum()==0 :
    print ("there is no missing data ")
# Out:
# there is no missing data

# %%
data.dtypes
# Out:
# tBodyAcc-mean()-X                       float64
# tBodyAcc-mean()-Y                       float64
# tBodyAcc-mean()-Z                       float64
# tBodyAcc-std()-X                        float64
# tBodyAcc-std()-Y                        float64
# tBodyAcc-std()-Z                        float64
# tBodyAcc-mad()-X                        float64
# tBodyAcc-mad()-Y                        float64
# tBodyAcc-mad()-Z                        float64
# tBodyAcc-max()-X                        float64
# tBodyAcc-max()-Y                        float64
# tBodyAcc-max()-Z                        float64
# tBodyAcc-min()-X                        float64
# tBodyAcc-min()-Y                        float64
# tBodyAcc-min()-Z                        float64
# tBodyAcc-sma()                          float64
# tBodyAcc-energy()-X                     float64
# tBodyAcc-energy()-Y                     float64
# tBodyAcc-energy()-Z                     float64
# tBodyAcc-iqr()-X                        float64
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# 5              0.277199          -0.010098          -0.105137
# 6              0.279454          -0.019641          -0.110022
# 7              0.277432          -0.030488          -0.125360
# 8              0.277293          -0.021751          -0.120751
# 9              0.280586          -0.009960          -0.106065
# 10             0.276880          -0.012722          -0.103438
# 11             0.276228          -0.021441          -0.108202
# 12             0.278457          -0.020415          -0.112732
# 13             0.277175          -0.014713          -0.106756
# ...

# %%
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
y= data["Activity"]
X= data.drop(col="Activity")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-75c59d82c0e6> in <module>()
#       1 y= data["Activity"]
# ----> 2 X= data.drop(axis="Activity")
#
# TypeError: drop() missing 1 required positional argument: 'labels'
